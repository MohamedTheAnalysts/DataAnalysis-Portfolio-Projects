# %%
# First let's import the packages we will use in this project
# You can do this all now or as you need them
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None



# Now we need to read in the data
df = pd.read_csv(r"C:\Users\hp\Desktop\Python tutorial\movies.csv.zip")

# %%
df
# Out:
#                                                 name rating      genre  year  \
# 0                                        The Shining      R      Drama  1980
# 1                                    The Blue Lagoon      R  Adventure  1980
# 2     Star Wars: Episode V - The Empire Strikes Back     PG     Action  1980
# 3                                          Airplane!     PG     Comedy  1980
# 4                                         Caddyshack      R     Comedy  1980
# ...                                              ...    ...        ...   ...
# 7663                                    More to Life    NaN      Drama  2020
# 7664                                     Dream Round    NaN     Comedy  2020
# 7665                                   Saving Mbango    NaN      Drama  2020
# 7666                                    It's Just Us    NaN      Drama  2020
# 7667                                       Tee em el    NaN     Horror  2020
#
#                               released  score      votes         director  \
# 0        June 13, 1980 (United States)    8.4   927000.0  Stanley Kubrick
# 1         July 2, 1980 (United States)    5.8    65000.0   Randal Kleiser
# 2        June 20, 1980 (United States)    8.7  1200000.0   Irvin Kershner
# 3         July 2, 1980 (United States)    7.7   221000.0     Jim Abrahams
# 4        July 25, 1980 (United States)    7.3   108000.0     Harold Ramis
# ...                                ...    ...        ...              ...
# 7663  October 23, 2020 (United States)    3.1       18.0    Joseph Ebanks
# 7664  February 7, 2020 (United States)    4.7       36.0     Dusty Dukatz
# 7665         April 27, 2020 (Cameroon)    5.7       29.0     Nkanya Nkwai
# 7666   October 1, 2020 (United States)    NaN        NaN    James Randall
# 7667   August 19, 2020 (United States)    5.7        7.0     Pereko Mosia
#
#                        writer              star         country      budget  \
# 0                Stephen King    Jack Nicholson  United Kingdom  19000000.0
# 1     Henry De Vere Stacpoole    Brooke Shields   United States   4500000.0
# 2              Leigh Brackett       Mark Hamill   United States  18000000.0
# 3                Jim Abrahams       Robert Hays   United States   3500000.0
# 4          Brian Doyle-Murray       Chevy Chase   United States   6000000.0
# ...                       ...               ...             ...         ...
# 7663            Joseph Ebanks      Shannon Bond   United States      7000.0
# 7664              Lisa Huston  Michael Saquella   United States         NaN
# 7665             Lynno Lovert      Onyama Laura   United States     58750.0
# 7666            James Randall     Christina Roz   United States     15000.0
# 7667             Pereko Mosia  Siyabonga Mabaso    South Africa         NaN
#
#             gross                    company  runtime
# 0      46998772.0               Warner Bros.    146.0
# 1      58853106.0          Columbia Pictures    104.0
# 2     538375067.0                  Lucasfilm    124.0
# 3      83453539.0         Paramount Pictures     88.0
# 4      39846344.0             Orion Pictures     98.0
# ...           ...                        ...      ...
# 7663          NaN                        NaN     90.0
# 7664          NaN  Cactus Blue Entertainment     90.0
# 7665          NaN           Embi Productions      NaN
# 7666          NaN                        NaN    120.0
# 7667          NaN                PK 65 Films    102.0
#
# [7668 rows x 15 columns]

# %%
df = df[sorted(df.columns)]
df
# Out:
#           budget                    company         country         director  \
# 0     19000000.0               Warner Bros.  United Kingdom  Stanley Kubrick
# 1      4500000.0          Columbia Pictures   United States   Randal Kleiser
# 2     18000000.0                  Lucasfilm   United States   Irvin Kershner
# 3      3500000.0         Paramount Pictures   United States     Jim Abrahams
# 4      6000000.0             Orion Pictures   United States     Harold Ramis
# ...          ...                        ...             ...              ...
# 7663      7000.0                        NaN   United States    Joseph Ebanks
# 7664         NaN  Cactus Blue Entertainment   United States     Dusty Dukatz
# 7665     58750.0           Embi Productions   United States     Nkanya Nkwai
# 7666     15000.0                        NaN   United States    James Randall
# 7667         NaN                PK 65 Films    South Africa     Pereko Mosia
#
#           genre        gross                                            name  \
# 0         Drama   46998772.0                                     The Shining
# 1     Adventure   58853106.0                                 The Blue Lagoon
# 2        Action  538375067.0  Star Wars: Episode V - The Empire Strikes Back
# 3        Comedy   83453539.0                                       Airplane!
# 4        Comedy   39846344.0                                      Caddyshack
# ...         ...          ...                                             ...
# 7663      Drama          NaN                                    More to Life
# 7664     Comedy          NaN                                     Dream Round
# 7665      Drama          NaN                                   Saving Mbango
# 7666      Drama          NaN                                    It's Just Us
# 7667     Horror          NaN                                       Tee em el
#
#      rating                          released  runtime  score  \
# 0         R     June 13, 1980 (United States)    146.0    8.4
# 1         R      July 2, 1980 (United States)    104.0    5.8
# 2        PG     June 20, 1980 (United States)    124.0    8.7
# 3        PG      July 2, 1980 (United States)     88.0    7.7
# 4         R     July 25, 1980 (United States)     98.0    7.3
# ...     ...                               ...      ...    ...
# 7663    NaN  October 23, 2020 (United States)     90.0    3.1
# 7664    NaN  February 7, 2020 (United States)     90.0    4.7
# 7665    NaN         April 27, 2020 (Cameroon)      NaN    5.7
# 7666    NaN   October 1, 2020 (United States)    120.0    NaN
# 7667    NaN   August 19, 2020 (United States)    102.0    5.7
#
#                   star      votes                   writer  year
# 0       Jack Nicholson   927000.0             Stephen King  1980
# 1       Brooke Shields    65000.0  Henry De Vere Stacpoole  1980
# 2          Mark Hamill  1200000.0           Leigh Brackett  1980
# 3          Robert Hays   221000.0             Jim Abrahams  1980
# 4          Chevy Chase   108000.0       Brian Doyle-Murray  1980
# ...                ...        ...                      ...   ...
# 7663      Shannon Bond       18.0            Joseph Ebanks  2020
# 7664  Michael Saquella       36.0              Lisa Huston  2020
# 7665      Onyama Laura       29.0             Lynno Lovert  2020
# 7666     Christina Roz        NaN            James Randall  2020
# 7667  Siyabonga Mabaso        7.0             Pereko Mosia  2020
#
# [7668 rows x 15 columns]

# %%
# We need to see if we have any missing data
# Let's loop through the data and see if there is anything missing

for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# budget - 28%
# company - 0%
# country - 0%
# director - 0%
# genre - 0%
# gross - 2%
# name - 0%
# rating - 1%
# released - 0%
# runtime - 0%
# score - 0%
# star - 0%
# votes - 0%
# writer - 0%
# year - 0%

# %%
# Data Types for our columns

print(df.dtypes)
# Out:
# budget      float64
# company      object
# country      object
# director     object
# genre        object
# gross       float64
# name         object
# rating       object
# released     object
# runtime     float64
# score       float64
# star         object
# votes       float64
# writer       object
# year          int64
# dtype: object

# %%
# Are there any Outliers?

df.boxplot(column=['gross'])
# Out:
# <Axes: >

# %%
df.drop_duplicates()
# Out:
#           budget                    company         country         director  \
# 0     19000000.0               Warner Bros.  United Kingdom  Stanley Kubrick
# 1      4500000.0          Columbia Pictures   United States   Randal Kleiser
# 2     18000000.0                  Lucasfilm   United States   Irvin Kershner
# 3      3500000.0         Paramount Pictures   United States     Jim Abrahams
# 4      6000000.0             Orion Pictures   United States     Harold Ramis
# ...          ...                        ...             ...              ...
# 7663      7000.0                        NaN   United States    Joseph Ebanks
# 7664         NaN  Cactus Blue Entertainment   United States     Dusty Dukatz
# 7665     58750.0           Embi Productions   United States     Nkanya Nkwai
# 7666     15000.0                        NaN   United States    James Randall
# 7667         NaN                PK 65 Films    South Africa     Pereko Mosia
#
#           genre        gross                                            name  \
# 0         Drama   46998772.0                                     The Shining
# 1     Adventure   58853106.0                                 The Blue Lagoon
# 2        Action  538375067.0  Star Wars: Episode V - The Empire Strikes Back
# 3        Comedy   83453539.0                                       Airplane!
# 4        Comedy   39846344.0                                      Caddyshack
# ...         ...          ...                                             ...
# 7663      Drama          NaN                                    More to Life
# 7664     Comedy          NaN                                     Dream Round
# 7665      Drama          NaN                                   Saving Mbango
# 7666      Drama          NaN                                    It's Just Us
# 7667     Horror          NaN                                       Tee em el
#
#      rating                          released  runtime  score  \
# 0         R     June 13, 1980 (United States)    146.0    8.4
# 1         R      July 2, 1980 (United States)    104.0    5.8
# 2        PG     June 20, 1980 (United States)    124.0    8.7
# 3        PG      July 2, 1980 (United States)     88.0    7.7
# 4         R     July 25, 1980 (United States)     98.0    7.3
# ...     ...                               ...      ...    ...
# 7663    NaN  October 23, 2020 (United States)     90.0    3.1
# 7664    NaN  February 7, 2020 (United States)     90.0    4.7
# 7665    NaN         April 27, 2020 (Cameroon)      NaN    5.7
# 7666    NaN   October 1, 2020 (United States)    120.0    NaN
# 7667    NaN   August 19, 2020 (United States)    102.0    5.7
#
#                   star      votes                   writer  year
# 0       Jack Nicholson   927000.0             Stephen King  1980
# 1       Brooke Shields    65000.0  Henry De Vere Stacpoole  1980
# 2          Mark Hamill  1200000.0           Leigh Brackett  1980
# 3          Robert Hays   221000.0             Jim Abrahams  1980
# 4          Chevy Chase   108000.0       Brian Doyle-Murray  1980
# ...                ...        ...                      ...   ...
# 7663      Shannon Bond       18.0            Joseph Ebanks  2020
# 7664  Michael Saquella       36.0              Lisa Huston  2020
# 7665      Onyama Laura       29.0             Lynno Lovert  2020
# 7666     Christina Roz        NaN            James Randall  2020
# 7667  Siyabonga Mabaso        7.0             Pereko Mosia  2020
#
# [7668 rows x 15 columns]

# %%
# Order our Data a little bit to see

df.sort_values(by=['gross'], inplace=False, ascending=False)
# Out:
#            budget                    company        country       director  \
# 5445  237000000.0      Twentieth Century Fox  United States  James Cameron
# 7445  356000000.0             Marvel Studios  United States  Anthony Russo
# 3045  200000000.0      Twentieth Century Fox  United States  James Cameron
# 6663  245000000.0                  Lucasfilm  United States    J.J. Abrams
# 7244  321000000.0             Marvel Studios  United States  Anthony Russo
# ...           ...                        ...            ...            ...
# 7663       7000.0                        NaN  United States  Joseph Ebanks
# 7664          NaN  Cactus Blue Entertainment  United States   Dusty Dukatz
# 7665      58750.0           Embi Productions  United States   Nkanya Nkwai
# 7666      15000.0                        NaN  United States  James Randall
# 7667          NaN                PK 65 Films   South Africa   Pereko Mosia
#
#        genre         gross                                        name rating  \
# 5445  Action  2.847246e+09                                      Avatar  PG-13
# 7445  Action  2.797501e+09                           Avengers: Endgame  PG-13
# 3045   Drama  2.201647e+09                                     Titanic  PG-13
# 6663  Action  2.069522e+09  Star Wars: Episode VII - The Force Awakens  PG-13
# 7244  Action  2.048360e+09                      Avengers: Infinity War  PG-13
# ...      ...           ...                                         ...    ...
# 7663   Drama           NaN                                More to Life    NaN
# 7664  Comedy           NaN                                 Dream Round    NaN
# 7665   Drama           NaN                               Saving Mbango    NaN
# 7666   Drama           NaN                                It's Just Us    NaN
# 7667  Horror           NaN                                   Tee em el    NaN
#
#                                released  runtime  score               star  \
# 5445  December 18, 2009 (United States)    162.0    7.8    Sam Worthington
# 7445     April 26, 2019 (United States)    181.0    8.4  Robert Downey Jr.
# 3045  December 19, 1997 (United States)    194.0    7.8  Leonardo DiCaprio
# 6663  December 18, 2015 (United States)    138.0    7.8       Daisy Ridley
# 7244     April 27, 2018 (United States)    149.0    8.4  Robert Downey Jr.
# ...                                 ...      ...    ...                ...
# 7663   October 23, 2020 (United States)     90.0    3.1       Shannon Bond
# 7664   February 7, 2020 (United States)     90.0    4.7   Michael Saquella
# 7665          April 27, 2020 (Cameroon)      NaN    5.7       Onyama Laura
# 7666    October 1, 2020 (United States)    120.0    NaN      Christina Roz
# 7667    August 19, 2020 (United States)    102.0    5.7   Siyabonga Mabaso
#
#           votes              writer  year
# 5445  1100000.0       James Cameron  2009
# 7445   903000.0  Christopher Markus  2019
# 3045  1100000.0       James Cameron  1997
# 6663   876000.0     Lawrence Kasdan  2015
# 7244   897000.0  Christopher Markus  2018
# ...         ...                 ...   ...
# 7663       18.0       Joseph Ebanks  2020
# 7664       36.0         Lisa Huston  2020
# 7665       29.0        Lynno Lovert  2020
# 7666        NaN       James Randall  2020
# 7667        7.0        Pereko Mosia  2020
#
# [7668 rows x 15 columns]

# %%
sns.regplot(x="gross", y="budget", data=df)
# Out:
# <Axes: xlabel='gross', ylabel='budget'>

# %%
sns.regplot(x="score", y="gross", data=df)
# Out:
# <Axes: xlabel='score', ylabel='gross'>

# %%
# Correlation Matrix between all numeric columns

df.corr(numeric_only=True)
# Out:
#            budget     gross   runtime     score     votes      year
# budget   1.000000  0.740395  0.320447  0.076254  0.442429  0.329321
# gross    0.740395  1.000000  0.245216  0.186258  0.630757  0.257486
# runtime  0.320447  0.245216  1.000000  0.399451  0.309212  0.120811
# score    0.076254  0.186258  0.399451  1.000000  0.409182  0.097995
# votes    0.442429  0.630757  0.309212  0.409182  1.000000  0.222945
# year     0.329321  0.257486  0.120811  0.097995  0.222945  1.000000

# %%
df.corr(method='pearson', numeric_only=True)
# Out:
#            budget     gross   runtime     score     votes      year
# budget   1.000000  0.740395  0.320447  0.076254  0.442429  0.329321
# gross    0.740395  1.000000  0.245216  0.186258  0.630757  0.257486
# runtime  0.320447  0.245216  1.000000  0.399451  0.309212  0.120811
# score    0.076254  0.186258  0.399451  1.000000  0.409182  0.097995
# votes    0.442429  0.630757  0.309212  0.409182  1.000000  0.222945
# year     0.329321  0.257486  0.120811  0.097995  0.222945  1.000000

# %%
df.corr(method ='kendall', numeric_only=True)
# Out:
#            budget     gross   runtime     score     votes      year
# budget   1.000000  0.512637  0.235483 -0.000566  0.353702  0.224120
# gross    0.512637  1.000000  0.168933  0.086046  0.548899  0.200618
# runtime  0.235483  0.168933  1.000000  0.283611  0.198240  0.097184
# score   -0.000566  0.086046  0.283611  1.000000  0.300115  0.067652
# votes    0.353702  0.548899  0.198240  0.300115  1.000000  0.331465
# year     0.224120  0.200618  0.097184  0.067652  0.331465  1.000000

# %%
df.corr(method ='spearman', numeric_only=True)
# Out:
#            budget     gross   runtime     score     votes      year
# budget   1.000000  0.693670  0.336370 -0.001403  0.502466  0.317336
# gross    0.693670  1.000000  0.246243  0.126116  0.742050  0.293084
# runtime  0.336370  0.246243  1.000000  0.399857  0.290159  0.142977
# score   -0.001403  0.126116  0.399857  1.000000  0.428138  0.099045
# votes    0.502466  0.742050  0.290159  0.428138  1.000000  0.469829
# year     0.317336  0.293084  0.142977  0.099045  0.469829  1.000000

# %%
correlation_matrix = df.corr(numeric_only=True)

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Numeric Features")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
# Using factorize - this assigns a random numeric value for each unique categorical value

df.apply(lambda x: x.factorize()[0]).corr(method='pearson')
# Out:
#             budget   company   country  director     genre     gross  \
# budget    1.000000 -0.092249 -0.082082  0.106617  0.073008  0.285832
# company  -0.092249  1.000000  0.226346  0.552258  0.009566  0.588156
# country  -0.082082  0.226346  1.000000  0.155471 -0.015795  0.133982
# director  0.106617  0.552258  0.155471  1.000000  0.047288  0.750911
# genre     0.073008  0.009566 -0.015795  0.047288  1.000000  0.038616
# gross     0.285832  0.588156  0.133982  0.750911  0.038616  1.000000
# name      0.277488  0.591667  0.142828  0.745905  0.036367  0.947324
# rating    0.193353 -0.028035  0.000494  0.085520 -0.086723  0.158582
# released  0.285691  0.607954  0.148468  0.770876  0.035940  0.976423
# runtime   0.112097  0.005137  0.124154 -0.011070  0.001462  0.042978
# score    -0.012642 -0.028432  0.023097 -0.022687 -0.002437 -0.047041
# star      0.107991  0.527116  0.182045  0.682385  0.038649  0.735680
# votes     0.398519  0.008900 -0.045914  0.192220  0.023285  0.286180
# writer    0.187238  0.546151  0.157202  0.748340  0.033688  0.805576
# year      0.300621  0.601571  0.140216  0.770497  0.037184  0.980873
#
#               name    rating  released   runtime     score      star  \
# budget    0.277488  0.193353  0.285691  0.112097 -0.012642  0.107991
# company   0.591667 -0.028035  0.607954  0.005137 -0.028432  0.527116
# country   0.142828  0.000494  0.148468  0.124154  0.023097  0.182045
# director  0.745905  0.085520  0.770876 -0.011070 -0.022687  0.682385
# genre     0.036367 -0.086723  0.035940  0.001462 -0.002437  0.038649
# gross     0.947324  0.158582  0.976423  0.042978 -0.047041  0.735680
# name      1.000000  0.143938  0.959015  0.048955 -0.046733  0.731565
# rating    0.143938  1.000000  0.146606  0.032741  0.012595  0.093116
# released  0.959015  0.146606  1.000000  0.048235 -0.045761  0.754468
# runtime   0.048955  0.032741  0.048235  1.000000  0.026436  0.035392
# score    -0.046733  0.012595 -0.045761  0.026436  1.000000 -0.009896
# star      0.731565  0.093116  0.754468  0.035392 -0.009896  1.000000
# votes     0.287776  0.099972  0.299905  0.106024 -0.009749  0.179601
# writer    0.805211  0.103623  0.819617  0.032264 -0.034685  0.675685
# year      0.965761  0.156713  0.993190  0.050647 -0.044981  0.756400
#
#              votes    writer      year
# budget    0.398519  0.187238  0.300621
# company   0.008900  0.546151  0.601571
# country  -0.045914  0.157202  0.140216
# director  0.192220  0.748340  0.770497
# genre     0.023285  0.033688  0.037184
# gross     0.286180  0.805576  0.980873
# name      0.287776  0.805211  0.965761
# rating    0.099972  0.103623  0.156713
# released  0.299905  0.819617  0.993190
# runtime   0.106024  0.032264  0.050647
# score    -0.009749 -0.034685 -0.044981
# star      0.179601  0.675685  0.756400
# votes     1.000000  0.224122  0.312401
# writer    0.224122  1.000000  0.824770
# year      0.312401  0.824770  1.000000

# %%
correlation_matrix = df.apply(lambda x: x.factorize()[0]).corr(method='pearson')

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Movies")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
correlation_mat = df.apply(lambda x: x.factorize()[0]).corr()

corr_pairs = correlation_mat.unstack()

print(corr_pairs)
# Out:
# budget  budget      1.000000
#         company    -0.092249
#         country    -0.082082
#         director    0.106617
#         genre       0.073008
#                       ...
# year    score      -0.044981
#         star        0.756400
#         votes       0.312401
#         writer      0.824770
#         year        1.000000
# Length: 225, dtype: float64

# %%
sorted_pairs = corr_pairs.sort_values(kind="quicksort")

print(sorted_pairs)
# Out:
# budget    company    -0.092249
# company   budget     -0.092249
# genre     rating     -0.086723
# rating    genre      -0.086723
# budget    country    -0.082082
#                         ...
# director  director    1.000000
# country   country     1.000000
# company   company     1.000000
# writer    writer      1.000000
# year      year        1.000000
# Length: 225, dtype: float64

# %%
# We can now take a look at the ones that have a high correlation (> 0.5)

strong_pairs = sorted_pairs[abs(sorted_pairs) > 0.5]

print(strong_pairs)
# Out:
# company   star        0.527116
# star      company     0.527116
# writer    company     0.546151
# company   writer      0.546151
# director  company     0.552258
#                         ...
#           director    1.000000
# country   country     1.000000
# company   company     1.000000
# writer    writer      1.000000
# year      year        1.000000
# Length: 71, dtype: float64

# %%
# Looking at the top 15 compaies by gross revenue

CompanyGrossSum = df.groupby('company')[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values('gross', ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company
# Warner Bros.                 56491421806
# Universal Pictures           52514188890
# Columbia Pictures            43008941346
# Paramount Pictures           40493607415
# Twentieth Century Fox        40257053857
# Walt Disney Pictures         36327887792
# New Line Cinema              19883797684
# Marvel Studios               15065592411
# DreamWorks Animation         11873612858
# Touchstone Pictures          11795832638
# Dreamworks Pictures          11635441081
# Metro-Goldwyn-Mayer (MGM)     9230230105
# Summit Entertainment          8373718838
# Pixar Animation Studios       7886344526
# Fox 2000 Pictures             7443502667
# Name: gross, dtype: int64

# %%
df['Year'] = df['released'].astype(str).str[:4]
df
# Out:
#           budget                    company         country         director  \
# 0     19000000.0               Warner Bros.  United Kingdom  Stanley Kubrick
# 1      4500000.0          Columbia Pictures   United States   Randal Kleiser
# 2     18000000.0                  Lucasfilm   United States   Irvin Kershner
# 3      3500000.0         Paramount Pictures   United States     Jim Abrahams
# 4      6000000.0             Orion Pictures   United States     Harold Ramis
# ...          ...                        ...             ...              ...
# 7663      7000.0                        NaN   United States    Joseph Ebanks
# 7664         NaN  Cactus Blue Entertainment   United States     Dusty Dukatz
# 7665     58750.0           Embi Productions   United States     Nkanya Nkwai
# 7666     15000.0                        NaN   United States    James Randall
# 7667         NaN                PK 65 Films    South Africa     Pereko Mosia
#
#           genre        gross                                            name  \
# 0         Drama   46998772.0                                     The Shining
# 1     Adventure   58853106.0                                 The Blue Lagoon
# 2        Action  538375067.0  Star Wars: Episode V - The Empire Strikes Back
# 3        Comedy   83453539.0                                       Airplane!
# 4        Comedy   39846344.0                                      Caddyshack
# ...         ...          ...                                             ...
# 7663      Drama          NaN                                    More to Life
# 7664     Comedy          NaN                                     Dream Round
# 7665      Drama          NaN                                   Saving Mbango
# 7666      Drama          NaN                                    It's Just Us
# 7667     Horror          NaN                                       Tee em el
#
#      rating                          released  runtime  score  \
# 0         R     June 13, 1980 (United States)    146.0    8.4
# 1         R      July 2, 1980 (United States)    104.0    5.8
# 2        PG     June 20, 1980 (United States)    124.0    8.7
# 3        PG      July 2, 1980 (United States)     88.0    7.7
# 4         R     July 25, 1980 (United States)     98.0    7.3
# ...     ...                               ...      ...    ...
# 7663    NaN  October 23, 2020 (United States)     90.0    3.1
# 7664    NaN  February 7, 2020 (United States)     90.0    4.7
# 7665    NaN         April 27, 2020 (Cameroon)      NaN    5.7
# 7666    NaN   October 1, 2020 (United States)    120.0    NaN
# 7667    NaN   August 19, 2020 (United States)    102.0    5.7
#
#                   star      votes                   writer  year  Year
# 0       Jack Nicholson   927000.0             Stephen King  1980  June
# 1       Brooke Shields    65000.0  Henry De Vere Stacpoole  1980  July
# 2          Mark Hamill  1200000.0           Leigh Brackett  1980  June
# 3          Robert Hays   221000.0             Jim Abrahams  1980  July
# 4          Chevy Chase   108000.0       Brian Doyle-Murray  1980  July
# ...                ...        ...                      ...   ...   ...
# 7663      Shannon Bond       18.0            Joseph Ebanks  2020  Octo
# 7664  Michael Saquella       36.0              Lisa Huston  2020  Febr
# 7665      Onyama Laura       29.0             Lynno Lovert  2020  Apri
# 7666     Christina Roz        NaN            James Randall  2020  Octo
# 7667  Siyabonga Mabaso        7.0             Pereko Mosia  2020  Augu
#
# [7668 rows x 16 columns]

# %%
df.groupby(['company', 'year'])[["gross"]].sum()
# Out:
#                                                 gross
# company                             year
# "DIA" Productions GmbH & Co. KG     2003   44350926.0
# "Weathering With You" Film Partners 2019  193457467.0
# .406 Production                     1996      10580.0
# 1+2 Seisaku Iinkai                  2000    1196218.0
# 10 West Studios                     2010     814906.0
# ...                                               ...
# i am OTHER                          2015   17986781.0
# i5 Films                            2001   10031529.0
# iDeal Partners Film Fund            2013     506303.0
# micro_scope                         2010    7099598.0
# thefyzz                             2017   62198461.0
#
# [4536 rows x 1 columns]

# %%
CompanyGrossSum = df.groupby(['company', 'year'])[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values(['gross','company','year'], ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company                year
# Walt Disney Pictures   2019    5773131804
# Marvel Studios         2018    4018631866
# Universal Pictures     2015    3834354888
# Twentieth Century Fox  2009    3793491246
# Walt Disney Pictures   2017    3789382071
# Paramount Pictures     2011    3565705182
# Warner Bros.           2010    3300479986
#                        2011    3223799224
# Walt Disney Pictures   2010    3104474158
# Paramount Pictures     2014    3071298586
# Columbia Pictures      2006    2934631933
#                        2019    2932757449
# Marvel Studios         2019    2797501328
# Warner Bros.           2018    2774168962
# Columbia Pictures      2011    2738363306
# Name: gross, dtype: int64

# %%
CompanyGrossSum = df.groupby(['company'])[["gross"]].sum()

CompanyGrossSumSorted = CompanyGrossSum.sort_values(['gross','company'], ascending = False)[:15]

CompanyGrossSumSorted = CompanyGrossSumSorted['gross'].astype('int64') 

CompanyGrossSumSorted
# Out:
# company
# Warner Bros.                 56491421806
# Universal Pictures           52514188890
# Columbia Pictures            43008941346
# Paramount Pictures           40493607415
# Twentieth Century Fox        40257053857
# Walt Disney Pictures         36327887792
# New Line Cinema              19883797684
# Marvel Studios               15065592411
# DreamWorks Animation         11873612858
# Touchstone Pictures          11795832638
# Dreamworks Pictures          11635441081
# Metro-Goldwyn-Mayer (MGM)     9230230105
# Summit Entertainment          8373718838
# Pixar Animation Studios       7886344526
# Fox 2000 Pictures             7443502667
# Name: gross, dtype: int64

# %%
plt.scatter(x=df['budget'], y=df['gross'], alpha=0.5)
plt.title('Budget vs Gross Earnings')
plt.xlabel('Gross Earnings')
plt.ylabel('Budget for Film')
plt.show()

# %%
df
# Out:
#           budget                    company         country         director  \
# 0     19000000.0               Warner Bros.  United Kingdom  Stanley Kubrick
# 1      4500000.0          Columbia Pictures   United States   Randal Kleiser
# 2     18000000.0                  Lucasfilm   United States   Irvin Kershner
# 3      3500000.0         Paramount Pictures   United States     Jim Abrahams
# 4      6000000.0             Orion Pictures   United States     Harold Ramis
# ...          ...                        ...             ...              ...
# 7663      7000.0                        NaN   United States    Joseph Ebanks
# 7664         NaN  Cactus Blue Entertainment   United States     Dusty Dukatz
# 7665     58750.0           Embi Productions   United States     Nkanya Nkwai
# 7666     15000.0                        NaN   United States    James Randall
# 7667         NaN                PK 65 Films    South Africa     Pereko Mosia
#
#           genre        gross                                            name  \
# 0         Drama   46998772.0                                     The Shining
# 1     Adventure   58853106.0                                 The Blue Lagoon
# 2        Action  538375067.0  Star Wars: Episode V - The Empire Strikes Back
# 3        Comedy   83453539.0                                       Airplane!
# 4        Comedy   39846344.0                                      Caddyshack
# ...         ...          ...                                             ...
# 7663      Drama          NaN                                    More to Life
# 7664     Comedy          NaN                                     Dream Round
# 7665      Drama          NaN                                   Saving Mbango
# 7666      Drama          NaN                                    It's Just Us
# 7667     Horror          NaN                                       Tee em el
#
#      rating                          released  runtime  score  \
# 0         R     June 13, 1980 (United States)    146.0    8.4
# 1         R      July 2, 1980 (United States)    104.0    5.8
# 2        PG     June 20, 1980 (United States)    124.0    8.7
# 3        PG      July 2, 1980 (United States)     88.0    7.7
# 4         R     July 25, 1980 (United States)     98.0    7.3
# ...     ...                               ...      ...    ...
# 7663    NaN  October 23, 2020 (United States)     90.0    3.1
# 7664    NaN  February 7, 2020 (United States)     90.0    4.7
# 7665    NaN         April 27, 2020 (Cameroon)      NaN    5.7
# 7666    NaN   October 1, 2020 (United States)    120.0    NaN
# 7667    NaN   August 19, 2020 (United States)    102.0    5.7
#
#                   star      votes                   writer  year  Year
# 0       Jack Nicholson   927000.0             Stephen King  1980  June
# 1       Brooke Shields    65000.0  Henry De Vere Stacpoole  1980  July
# 2          Mark Hamill  1200000.0           Leigh Brackett  1980  June
# 3          Robert Hays   221000.0             Jim Abrahams  1980  July
# 4          Chevy Chase   108000.0       Brian Doyle-Murray  1980  July
# ...                ...        ...                      ...   ...   ...
# 7663      Shannon Bond       18.0            Joseph Ebanks  2020  Octo
# 7664  Michael Saquella       36.0              Lisa Huston  2020  Febr
# 7665      Onyama Laura       29.0             Lynno Lovert  2020  Apri
# 7666     Christina Roz        NaN            James Randall  2020  Octo
# 7667  Siyabonga Mabaso        7.0             Pereko Mosia  2020  Augu
#
# [7668 rows x 16 columns]

# %%
df_numerized = df


for col_name in df_numerized.columns:
    if(df_numerized[col_name].dtype == 'object'):
        df_numerized[col_name]= df_numerized[col_name].astype('category')
        df_numerized[col_name] = df_numerized[col_name].cat.codes
        
df_numerized
# Out:
#           budget  company  country  director  genre        gross  name  \
# 0     19000000.0     2319       54      2589      6   46998772.0  6587
# 1      4500000.0      731       55      2269      1   58853106.0  5573
# 2     18000000.0     1540       55      1111      0  538375067.0  5142
# 3      3500000.0     1812       55      1301      4   83453539.0   286
# 4      6000000.0     1777       55      1054      4   39846344.0  1027
# ...          ...      ...      ...       ...    ...          ...   ...
# 7663      7000.0       -1       55      1500      6          NaN  3705
# 7664         NaN      539       55       774      4          NaN  1678
# 7665     58750.0      941       55      2061      6          NaN  4717
# 7666     15000.0       -1       55      1184      6          NaN  2843
# 7667         NaN     1787       44      2165     10          NaN  5394
#
#       rating  released  runtime  score  star      votes  writer  year  Year
# 0          6      1705    146.0    8.4  1047   927000.0    4014  1980    14
# 1          6      1492    104.0    5.8   327    65000.0    1632  1980    13
# 2          4      1771    124.0    8.7  1745  1200000.0    2567  1980    14
# 3          4      1492     88.0    7.7  2246   221000.0    2000  1980    13
# 4          6      1543     98.0    7.3   410   108000.0     521  1980    13
# ...      ...       ...      ...    ...   ...        ...     ...   ...   ...
# 7663      -1      2964     90.0    3.1  2421       18.0    2289  2020    18
# 7664      -1      1107     90.0    4.7  1886       36.0    2614  2020    11
# 7665      -1       193      NaN    5.7  2040       29.0    2683  2020     8
# 7666      -1      2817    120.0    NaN   450        NaN    1824  2020    18
# 7667      -1       391    102.0    5.7  2463        7.0    3344  2020     9
#
# [7668 rows x 16 columns]

# %%
df_numerized.corr(method='pearson', numeric_only=True)
# Out:
#             budget   company   country  director     genre     gross  \
# budget    1.000000  0.173214  0.054063 -0.012272 -0.356564  0.740395
# company   0.173214  1.000000  0.095548  0.004404 -0.071067  0.154840
# country   0.054063  0.095548  1.000000  0.017490 -0.037615  0.092129
# director -0.012272  0.004404  0.017490  1.000000 -0.015258 -0.014441
# genre    -0.356564 -0.071067 -0.037615 -0.015258  1.000000 -0.235650
# gross     0.740395  0.154840  0.092129 -0.014441 -0.235650  1.000000
# name      0.023970  0.009211 -0.010737  0.009079  0.016355  0.005533
# rating   -0.176002 -0.032943  0.081244  0.019483  0.072423 -0.107339
# released  0.014683 -0.010474 -0.020427 -0.001478  0.029822  0.001659
# runtime   0.320447  0.034402 -0.078412  0.017624 -0.052711  0.245216
# score     0.076254  0.001030 -0.133348  0.009559  0.027965  0.186258
# star     -0.019589  0.012442 -0.012998  0.039234 -0.005477 -0.002717
# votes     0.442429  0.133204  0.073625  0.000260 -0.145307  0.630757
# writer   -0.039451  0.005646  0.015343  0.299067  0.006567 -0.023519
# year      0.329321 -0.010431 -0.070938 -0.020795 -0.081261  0.257486
# Year      0.015682 -0.010726 -0.022277 -0.000105  0.028397  0.002946
#
#               name    rating  released   runtime     score      star  \
# budget    0.023970 -0.176002  0.014683  0.320447  0.076254 -0.019589
# company   0.009211 -0.032943 -0.010474  0.034402  0.001030  0.012442
# country  -0.010737  0.081244 -0.020427 -0.078412 -0.133348 -0.012998
# director  0.009079  0.019483 -0.001478  0.017624  0.009559  0.039234
# genre     0.016355  0.072423  0.029822 -0.052711  0.027965 -0.005477
# gross     0.005533 -0.107339  0.001659  0.245216  0.186258 -0.002717
# name      1.000000 -0.008069 -0.011311  0.010392  0.017097  0.006472
# rating   -0.008069  1.000000  0.016613  0.062145 -0.001314  0.013405
# released -0.011311  0.016613  1.000000  0.000868  0.042788  0.015777
# runtime   0.010392  0.062145  0.000868  1.000000  0.399451  0.010174
# score     0.017097 -0.001314  0.042788  0.399451  1.000000 -0.001609
# star      0.006472  0.013405  0.015777  0.010174 -0.001609  1.000000
# votes     0.013088  0.033225  0.016097  0.309212  0.409182 -0.019282
# writer    0.009081 -0.005921 -0.002404 -0.003511  0.019416  0.027245
# year      0.011453  0.008779 -0.000695  0.120811  0.097995 -0.027242
# Year     -0.011725  0.013475  0.993694  0.000410  0.040993  0.015406
#
#              votes    writer      year      Year
# budget    0.442429 -0.039451  0.329321  0.015682
# company   0.133204  0.005646 -0.010431 -0.010726
# country   0.073625  0.015343 -0.070938 -0.022277
# director  0.000260  0.299067 -0.020795 -0.000105
# genre    -0.145307  0.006567 -0.081261  0.028397
# gross     0.630757 -0.023519  0.257486  0.002946
# name      0.013088  0.009081  0.011453 -0.011725
# rating    0.033225 -0.005921  0.008779  0.013475
# released  0.016097 -0.002404 -0.000695  0.993694
# runtime   0.309212 -0.003511  0.120811  0.000410
# score     0.409182  0.019416  0.097995  0.040993
# star     -0.019282  0.027245 -0.027242  0.015406
# votes     1.000000  0.000892  0.222945  0.017337
# writer    0.000892  1.000000 -0.008656 -0.002892
# year      0.222945 -0.008656  1.000000 -0.001562
# Year      0.017337 -0.002892 -0.001562  1.000000

# %%
correlation_matrix = df_numerized.corr(method='pearson', numeric_only=True)

sns.heatmap(correlation_matrix, annot = True)

plt.title("Correlation matrix for Movies")

plt.xlabel("Movie features")

plt.ylabel("Movie features")

plt.show()

# %%
for col_name in df.columns:
    if df[col_name].dtype == 'object':
        df[col_name] = df[col_name].astype('category')
        df[col_name] = df[col_name].cat.codes

# Display the DataFrame
df
# Out:
#           budget  company  country  director  genre        gross  name  \
# 0     19000000.0     2319       54      2589      6   46998772.0  6587
# 1      4500000.0      731       55      2269      1   58853106.0  5573
# 2     18000000.0     1540       55      1111      0  538375067.0  5142
# 3      3500000.0     1812       55      1301      4   83453539.0   286
# 4      6000000.0     1777       55      1054      4   39846344.0  1027
# ...          ...      ...      ...       ...    ...          ...   ...
# 7663      7000.0       -1       55      1500      6          NaN  3705
# 7664         NaN      539       55       774      4          NaN  1678
# 7665     58750.0      941       55      2061      6          NaN  4717
# 7666     15000.0       -1       55      1184      6          NaN  2843
# 7667         NaN     1787       44      2165     10          NaN  5394
#
#       rating  released  runtime  score  star      votes  writer  year  Year
# 0          6      1705    146.0    8.4  1047   927000.0    4014  1980    14
# 1          6      1492    104.0    5.8   327    65000.0    1632  1980    13
# 2          4      1771    124.0    8.7  1745  1200000.0    2567  1980    14
# 3          4      1492     88.0    7.7  2246   221000.0    2000  1980    13
# 4          6      1543     98.0    7.3   410   108000.0     521  1980    13
# ...      ...       ...      ...    ...   ...        ...     ...   ...   ...
# 7663      -1      2964     90.0    3.1  2421       18.0    2289  2020    18
# 7664      -1      1107     90.0    4.7  1886       36.0    2614  2020    11
# 7665      -1       193      NaN    5.7  2040       29.0    2683  2020     8
# 7666      -1      2817    120.0    NaN   450        NaN    1824  2020    18
# 7667      -1       391    102.0    5.7  2463        7.0    3344  2020     9
#
# [7668 rows x 16 columns]

# %%
sns.stripplot(x="rating", y="gross", data=df, jitter=True, alpha=0.3)
# Out:
# <Axes: xlabel='rating', ylabel='gross'>

# %%
sns.stripplot(x="rating", y="gross", data=df, jitter=True, alpha=0.3)
# Out:
# <Axes: xlabel='rating', ylabel='gross'>

# %%
sns.boxplot(x="rating", y="gross", data=df)
sns.stripplot(x="rating", y="gross", data=df, jitter=True, alpha=0.2, color='black')
plt.yscale("log")
plt.show()
